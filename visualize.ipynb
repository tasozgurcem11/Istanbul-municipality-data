# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Read municipality data

# %%
fuel_stations = pd.read_csv('data/export/fuel_stations.csv')
fuel_stations.head()
# Out:
#     LATITUDE  LONGITUDE
# 0  41.012617  28.541407
# 1  41.158161  28.613566
# 2  41.249339  28.037783
# 3  40.983899  29.040094
# 4  41.000576  28.691463

# %%
kiosk_locations = pd.read_csv('data/export/kiosk_locations.csv')
kiosk_locations.head()
# Out:
#    ID   LATITUDE  LONGITUDE
# 0   1  40.946814  29.111346
# 1   2  41.008402  29.218715
# 2   3  41.042820  28.680489
# 3   4  41.048987  28.963690
# 4   5  40.996731  28.776361

# %%
number_of_wifi_users = pd.read_csv('data/export/number_of_users.csv')
number_of_wifi_users.head()
# Out:
#        Location      2019     2020   2021
# 0     PDM Fatih         8        0      0
# 1    IETT-O3041    509771    71799   1710
# 2  ISKI-Esenler   1504313  1243715  11428
# 3          Null  25120646     4612    282
# 4    IETT-B5060    129208    38182    635

# %%
parking_lots = pd.read_csv('data/export/parking_lots.csv')
parking_lots.head()
# Out:
#    ID  CAPACITY_OF_PARK WORKING_TIME  LONGITUDE   LATITUDE
# 0   1                30  08:00-19:00  28.987975  41.048823
# 1   2                50  08:00-19:00  28.995566  41.049523
# 2   3                50  08:00-19:00  28.994976  41.048390
# 3   4                50  08:00-19:00  28.995974  41.053386
# 4   5                40  08:00-00:00  28.992955  41.046630

# %%
wifi_locations = pd.read_csv('data/export/wifi_locations.csv')
wifi_locations.head()
# Out:
#    ID    LOCATION_GROUP  LONGITUDE   LATITUDE
# 0   1  Service Building  28.843808  41.122220
# 1   2  Service Building  28.751046  41.179543
# 2   3  Service Building  29.147271  40.977937
# 3   4  Service Building  28.825496  40.997055
# 4   5  Service Building  28.825249  40.997040

# %%
mapbox_access_token = "{YOUR_PLOTLY_ACCESS_TOKEN}"

fig = go.Figure(go.Scattermapbox(

        lat=parking_lots['LATITUDE'],
        lon=parking_lots['LONGITUDE'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=5
        ),
    text=parking_lots['CAPACITY_OF_PARK'].apply(lambda x: f'Parking lot capacity:{str(x)}')
    ))

fig.update_layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=41.1,
            lon=29
        ),
        pitch=0,
        zoom=8
    ),
)

fig.show()
# Out:
# <div>                            <div id="c62dcdbc-ba61-4654-af0e-5b4af8bcc462" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c62dcdbc-ba61-4654-af0e-5b4af8bcc462")) {                    Plotly.newPlot(                        "c62dcdbc-ba61-4654-af0e-5b4af8bcc462",                        [{"lat": [41.0488233569155, 41.049523298771696, 41.0483895406422, 41.053386199907294, 41.0466296925246, 41.04782937015631, 41.0479375617614, 41.0655057224779, 41.0688297324025, 41.025531237132, 41.043801637794, 41.0463832988957, 41.0525791949699, 41.025309859884494, 41.0754029841827, 41.0759943082714, 41.0249386157846, 41.022542970427295, 41.0241210457322, 40.9920091951619, 40.992844048405, 41.03618849195, 41.0122623682819, 41.0854593814072, 41.1149636096173, 41.1
# ...

# %%
mapbox_access_token = "{YOUR_PLOTLY_ACCESS_TOKEN}"

fig = go.Figure(go.Scattermapbox(
        lat=fuel_stations['LATITUDE'],
        lon=fuel_stations['LONGITUDE'],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=5
        ),
    ))

fig.update_layout(
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=41.1,
            lon=29
        ),
        pitch=0,
        zoom=8
    ),
)

fig.show()
# Out:
# <div>                            <div id="a95918b1-5fee-4f9d-9f45-0b7c721c04e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a95918b1-5fee-4f9d-9f45-0b7c721c04e3")) {                    Plotly.newPlot(                        "a95918b1-5fee-4f9d-9f45-0b7c721c04e3",                        [{"lat": [41.01261672, 41.15816138, 41.24933896, 40.98389906, 41.00057571, 40.93530869, 41.01450221, 40.98940391, 41.02753436, 40.98987317, 40.89141356, 41.13060422, 41.04165762, 41.00306655, 41.03232541, 41.02096585, 41.0800035, 40.86945447, 41.01967015, 41.03100559, 40.90436916, 41.06142149, 40.98152792, 41.03474573, 41.04161852, 41.11363622, 41.0225188, 40.8967308, 40.98186429, 41.05997752, 41.05681212, 40.97177557, 41.07384915, 41.02608257, 41.13673143, 41.004
# ...
